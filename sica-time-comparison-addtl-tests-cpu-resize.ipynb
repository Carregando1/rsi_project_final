# %% [markdown]
# SICA Time Comparison- Additional Tests - Only Compatible with Attempt 2- Only for Time Complexity Calculations for Attempt 2- Only CPU

# %% [markdown]
# Part 1: Dataset Generation

# %% [markdown]
# Step 1: Import relevant state functions and packages

# %%
from cax_sica.genetic.state import CurrentState as st2

import numpy as np
import jax.numpy as jnp
import time
from typing import List, Tuple

# %% [markdown]
# Part 2: Testing Dim/Num Timesteps against Time Required for SICA Simulation: Trial 1: Dim Testing

# %%
#Requires  bit less than 2 hours of runtime.
data: List[Tuple] = []
iter = 6
def generateicsrt(dim, num_steps, example = 0):
    ic = np.random.choice([0,0,0,1], size=(dim, dim))
    srt = np.random.choice([0,0,0,0,0,1], size=(num_steps, dim, dim, 18))
    return ic, srt
for i in range(100, 1010, 10):
    print(f"OPERATING DIM: {i}")
    for _ in range(iter):
        print(f"ITER {_}")
        stepdim = [i,100,0]
        icsrt = generateicsrt(stepdim[0], stepdim[1])
        ic = icsrt[0]
        srt = icsrt[1]
        time_init = time.time()
        state = st2(initial=ic, rules=srt)
        st2res = state.generate()
        data.append((i,time.time()-time_init))
# Out:
# OPERATING DIM: 100
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 110
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 120
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 130
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 140
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 150
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 160
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 170
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 180
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 190
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 200
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 210
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 220
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 230
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 240
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 250
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 260
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 270
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 280
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 290
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 300
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 310
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 320
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 330
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 340
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 350
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 360
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 370
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 380
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 390
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 400
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 410
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 420
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 430
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 440
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 450
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 460
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 470
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 480
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 490
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 500
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 510
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 520
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 530
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 540
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 550
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 560
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 570
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 580
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 590
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 600
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 610
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 620
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 630
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 640
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 650
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 660
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 670
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 680
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 690
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 700
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 710
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 720
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 730
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 740
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 750
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 760
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 770
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 780
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 790
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 800
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 810
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 820
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 830
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 840
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 850
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 860
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 870
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 880
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 890
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 900
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 910
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 920
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 930
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 940
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 950
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 960
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 970
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 980
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 990
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING DIM: 1000
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5

# %% [markdown]
# Trial 2: Timestep Testing

# %%
#Requires a little less than an hour of runtime.
data_time: List[Tuple] = []
iter = 6
def generateicsrt(dim, num_steps, example = 0):
    ic = np.random.choice([0,0,0,1], size=(dim, dim))
    srt = np.random.choice([0,0,0,0,0,1], size=(num_steps, dim, dim, 18))
    return ic, srt
for i in range(100, 1010, 10):
    print(f"OPERATING TIMESTEP CT: {i}")
    for _ in range(iter):
        print(f"ITER {_}")
        stepdim = [200,i,0]
        icsrt = generateicsrt(stepdim[0], stepdim[1])
        ic = icsrt[0]
        srt = icsrt[1]
        time_init = time.time()
        state = st2(initial=ic, rules=srt)
        st2res = state.generate()
        data_time.append((i,time.time()-time_init))
# Out:
# OPERATING TIMESTEP CT: 100
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 110
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 120
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 130
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 140
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 150
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 160
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 170
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 180
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 190
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 200
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 210
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 220
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 230
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 240
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 250
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 260
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 270
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 280
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 290
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 300
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 310
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 320
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 330
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 340
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 350
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 360
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 370
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 380
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 390
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 400
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 410
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 420
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 430
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 440
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 450
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 460
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 470
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 480
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 490
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 500
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 510
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 520
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 530
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 540
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 550
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 560
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 570
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 580
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 590
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 600
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 610
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 620
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 630
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 640
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 650
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 660
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 670
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 680
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 690
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 700
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 710
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 720
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 730
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 740
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 750
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 760
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 770
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 780
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 790
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 800
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 810
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 820
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 830
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 840
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 850
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 860
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 870
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 880
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 890
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 900
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 910
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 920
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 930
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 940
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 950
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 960
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 970
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 980
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 990
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5
# OPERATING TIMESTEP CT: 1000
# ITER 0
# ITER 1
# ITER 2
# ITER 3
# ITER 4
# ITER 5

# %% [markdown]
# Step 3: Report results (Optional, used for data export)

# %%
print(data)
print(data_time)
# Out:
# [(100, 1.514634370803833), (100, 0.04549145698547363), (100, 0.05079245567321777), (100, 0.0414576530456543), (100, 0.04231595993041992), (100, 0.0424189567565918), (110, 0.4310026168823242), (110, 0.029984474182128906), (110, 0.042428016662597656), (110, 0.04730033874511719), (110, 0.04347538948059082), (110, 0.03160357475280762), (120, 0.4546811580657959), (120, 0.05292868614196777), (120, 0.0816793441772461), (120, 0.05534958839416504), (120, 0.05978226661682129), (120, 0.05249762535095215), (130, 0.5397117137908936), (130, 0.06868743896484375), (130, 0.10269451141357422), (130, 0.06238842010498047), (130, 0.07062649726867676), (130, 0.0666654109954834), (140, 0.5107171535491943), (140, 0.06899666786193848), (140, 0.0781700611114502), (140, 0.09653139114379883), (140, 0.0690922737121582), (140, 0.08372735977172852), (150, 0.5167343616485596), (150, 0.08204483985900879), (150, 0.06950020790100098), (150, 0.06873416900634766), (150, 0.0834646224975586), (150, 0.11406159400939941), (160, 0.5328311920166016), (160, 0.08729910850524902), (160, 0.10318875312805176), (160, 0.09530067443847656), (160, 0.10396313667297363), (160, 0.10006332397460938), (170, 0.5170011520385742), (170, 0.10409665107727051), (170, 0.10114169120788574), (170, 0.16517090797424316), (170, 0.10217618942260742), (170, 0.10007190704345703), (180, 0.5516507625579834), (180, 0.10001492500305176), (180, 0.10102581977844238), (180, 0.11513090133666992), (180, 0.11675834655761719), (180, 0.11674690246582031), (190, 0.5751934051513672), (190, 0.12760519981384277), (190, 0.11678552627563477), (190, 0.1375741958618164), (190, 0.1170966625213623), (190, 0.12201905250549316), (200, 0.581566333770752), (200, 0.13340163230895996), (200, 0.1421959400177002), (200, 0.21678805351257324), (200, 0.1398448944091797), (200, 0.13975977897644043), (210, 0.6324455738067627), (210, 0.16732144355773926), (210, 0.15404558181762695), (210, 0.16438579559326172), (210, 0.15473651885986328), (210, 0.1491537094116211), (220, 0.68499755859375), (220, 0.15127968788146973), (220, 0.21870636940002441), (220, 0.16672062873840332), (220, 0.17803120613098145), (220, 0.18182873725891113), (230, 0.6832718849182129), (230, 0.17078828811645508), (230, 0.18625974655151367), (
# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.metrics import r2_score

# %% [markdown]
# Step 2: Generate plot arrays

# %%
#Adjust these values to be 455 - number of outliers.

dim_x = np.zeros((448))
dim_y = np.zeros((448))
step_x = np.zeros((454))
step_y = np.zeros((454))

#Remove first trials as they are outliers, as well as trial-specific outliers (dim: > 5.5s, step: > 2s)
dim_out = 0
step_out = 0
for i in range(0, len(data)):
    if (i%6):
        if (data[i][1] < 5.5):
            dim_x[i-1-int(np.floor(i/6)) - dim_out] = data[i][0]
            dim_y[i-1-int(np.floor(i/6)) - dim_out] = data[i][1]
        else:
            dim_out += 1
for i in range(0, len(data_time)):
    if (i%6):
        if (data_time[i][1] < 2):
            step_x[i-1-int(np.floor(i/6)) - step_out] = data_time[i][0]
            step_y[i-1-int(np.floor(i/6)) - step_out] = data_time[i][1]
        else:
            step_out += 1

# %% [markdown]
# Step 3: Perform test regressions (target: dim: quadratic; timestep: linear) and plot; evaluate using R²

# %%
dim = stats.linregress(dim_x, dim_y)
step = stats.linregress(step_x, step_y)

"""Dim plots."""
#O(n) fit
plt.figure().set_figheight(3)
plt.plot(dim_x, dim_y, 'o')
plt.plot(dim_x, dim.intercept + dim.slope*dim_x, 'r')
plt.xlabel(f"Dim \n\n R-squared value: {dim.rvalue**2:.6}")
plt.ylabel("Runtime (seconds)")
plt.title("CPU Dimension Simulation: Linear Fit")
plt.show()

#O(n log n) fit
dimn15 = np.poly1d(np.polyfit((dim_x * np.log(dim_x)), dim_y, 1))
pdimn15 = np.linspace(100, 1000, 1000)
plt.figure().set_figheight(3)
plt.plot(dim_x, dim_y, 'o')
plt.plot(pdimn15, dimn15(pdimn15*np.log(pdimn15)), 'r')
plt.xlabel(f"Dim \n\n R-squared value: {r2_score(dim_y, dimn15(dim_x*np.log(dim_x))):.6f}")
plt.ylabel("Runtime (seconds)")
plt.title("CPU Dimension Simulation: Linear-Logarithmic Fit")
plt.show()

#O(n²) fit
dimn2 = np.poly1d(np.polyfit(dim_x, dim_y, 2))
pdimn2 = np.linspace(100, 1000, 1000)
plt.figure().set_figheight(3)
plt.plot(dim_x, dim_y, 'o')
plt.plot(pdimn2, dimn2(pdimn2), 'r')
plt.xlabel(f"Dim \n\n R-squared value: {r2_score(dim_y, dimn2(dim_x)):.6f}")
plt.ylabel("Runtime (seconds)")
plt.title("CPU Dimension Simulation: Quadratic Fit")
plt.show()

#O(n² log n) fit
dimn25 = np.poly1d(np.polyfit((dim_x * dim_x * np.log(dim_x)), dim_y, 1))
pdimn25 = np.linspace(100, 1000, 1000)
plt.figure().set_figheight(3)
plt.plot(dim_x, dim_y, 'o')
plt.plot(pdimn25, dimn25(pdimn25*pdimn25*np.log(pdimn25)), 'r')
plt.xlabel(f"Dim \n\n R-squared value: {r2_score(dim_y, dimn25(dim_x*dim_x*np.log(dim_x))):.6f}")
plt.ylabel("Runtime (seconds)")
plt.title("CPU Dimension Simulation: Quadratic-Logarithmic Fit")
plt.show()

#O(n^3) fit
dimn3 = np.poly1d(np.polyfit(dim_x, dim_y, 3))
pdimn3 = np.linspace(100, 1000, 1000)
plt.figure().set_figheight(3)
plt.plot(dim_x, dim_y, 'o')
plt.plot(pdimn3, dimn3(pdimn3), 'r')
plt.xlabel(f"Dim \n\n R-squared value: {r2_score(dim_y, dimn3(dim_x)):.6f}")
plt.ylabel("Runtime (seconds)")
plt.title("CPU Dimension Simulation: Cubic Fit")
plt.show()

"""Timestep plots."""
#O(n) fit
plt.plot(step_x, step_y, 'o', label='original data')
plt.plot(step_x, step.intercept + step.slope*step_x, 'r')
plt.xlabel(f"Number of SICA timesteps simulated \n\n R-squared value: {step.rvalue**2:.6f}")
plt.ylabel("Runtime (seconds)")
plt.title("CPU Timestep Simulation: Linear Fit")
plt.show()

#O(n log n) fit
timn15 = np.poly1d(np.polyfit((step_x * np.log(step_x)), step_y, 1))
ptimn15 = np.linspace(100, 1000, 1000)
plt.figure().set_figheight(3)
plt.plot(step_x, step_y, 'o')
plt.plot(ptimn15, timn15(ptimn15*np.log(ptimn15)), 'r')
plt.xlabel(f"Number of SICA timesteps simulated \n\n R-squared value: {r2_score(step_y, timn15(step_x*np.log(step_x))):.6f}")
plt.ylabel("Runtime (seconds)")
plt.title("CPU Timestep Simulation: Linear-Logarithmic Fit")
plt.show()

#O(n²) fit
timn2 = np.poly1d(np.polyfit(step_x, step_y, 2))
ptimn2 = np.linspace(100, 1000, 1000)
plt.figure().set_figheight(3)
plt.plot(step_x, step_y, 'o')
plt.plot(ptimn2, timn2(ptimn2), 'r')
plt.xlabel(f"Number of SICA timesteps simulated \n\n R-squared value: {r2_score(step_y, timn2(step_x)):.6f}")
plt.ylabel("Runtime (seconds)")
plt.title("CPU Timestep Simulation: Quadratic Fit")
plt.show()

#O(n² log n) fit
timn25 = np.poly1d(np.polyfit((step_x * step_x * np.log(step_x)), step_y, 1))
ptimn25 = np.linspace(100, 1000, 1000)
plt.figure().set_figheight(3)
plt.plot(step_x, step_y, 'o')
plt.plot(ptimn25, timn25(ptimn25*ptimn25*np.log(ptimn25)), 'r')
plt.xlabel(f"Number of SICA timesteps simulated \n\n R-squared value: {r2_score(step_y, timn25(step_x*step_x*np.log(step_x))):.6f}")
plt.ylabel("Runtime (seconds)")
plt.title("CPU Timestep Simulation: Quadratic-Logarithmic Fit")
plt.show()

#O(n^3) fit
timn3 = np.poly1d(np.polyfit(step_x, step_y, 3))
ptimn3 = np.linspace(100, 1000, 1000)
plt.figure().set_figheight(3)
plt.plot(step_x, step_y, 'o')
plt.plot(ptimn3, timn3(ptimn3), 'r')
plt.xlabel(f"Number of SICA timesteps simulated \n\n R-squared value: {r2_score(step_y, timn3(step_x)):.6f}")
plt.ylabel("Runtime (seconds)")
plt.title("CPU Timestep Simulation: Cubic Fit")
plt.show()
